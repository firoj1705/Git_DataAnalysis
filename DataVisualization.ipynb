# %%
import pandas as pd
import seaborn as sns

# %%
auto=pd.read_csv("Automobile.csv")
auto.head()
# Out:
#    symboling  normalized_losses         make fuel_type aspiration  \
# 0          3                168  alfa-romero       gas        std
# 1          3                168  alfa-romero       gas        std
# 2          1                168  alfa-romero       gas        std
# 3          2                164         audi       gas        std
# 4          2                164         audi       gas        std
#
#   number_of_doors   body_style drive_wheels engine_location  wheel_base  ...  \
# 0             two  convertible          rwd           front        88.6  ...
# 1             two  convertible          rwd           front        88.6  ...
# 2             two    hatchback          rwd           front        94.5  ...
# 3            four        sedan          fwd           front        99.8  ...
# 4            four        sedan          4wd           front        99.4  ...
#
#    engine_size  fuel_system  bore  stroke compression_ratio horsepower  \
# ...

# %%
sns.displot(x='normalized_losses', y='engine_size', data=auto)

# %%
sns.displot(x='normalized_losses', y='engine_size', data=auto, hue='engine_location')

# %%
sns.relplot(x='normalized_losses', y='engine_size', data=auto)

# %%
sns.displot(x='normalized_losses',data=auto)

# %%
sns.displot(x='normalized_losses',data=auto, kde=True)

# %%
sns.barplot(x='normalized_losses', y='engine_size', data=auto)
# Out:
# <AxesSubplot:xlabel='normalized_losses', ylabel='engine_size'>

# %%
sns.swarmplot(x='normalized_losses', y='engine_size', data=auto)
# Out:
# c:\users\shree\appdata\local\programs\python\python39\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 60.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# c:\users\shree\appdata\local\programs\python\python39\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 20.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# c:\users\shree\appdata\local\programs\python\python39\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 50.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# c:\users\shree\appdata\local\programs\python\python39\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 33.3% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
# ...

# %%
sns.stripplot(x='normalized_losses', y='engine_size', data=auto)
# Out:
# <AxesSubplot:xlabel='normalized_losses', ylabel='engine_size'>

# %%
sns.swarmplot(x='fuel_type', y='normalized_losses',hue='engine_location', data=auto)
# Out:
# <AxesSubplot:xlabel='fuel_type', ylabel='normalized_losses'>

# %%
sns.violinplot(x='fuel_type', y='normalized_losses',hue='engine_location', data=auto)
# Out:
# <AxesSubplot:xlabel='fuel_type', ylabel='normalized_losses'>

# %%
sns.countplot(x='normalized_losses',hue='engine_location', data=auto)
# Out:
# <AxesSubplot:xlabel='normalized_losses', ylabel='count'>

# %%
sns.swarmplot(auto['fuel_type'],auto['normalized_losses'],hue='engine_location', data=auto)
# Out:
# c:\users\shree\appdata\local\programs\python\python39\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='fuel_type', ylabel='normalized_losses'>

# %%
sns.histplot(x='fuel_type', y='normalized_losses',hue='engine_location', data=auto)
# Out:
# <AxesSubplot:xlabel='fuel_type', ylabel='normalized_losses'>
